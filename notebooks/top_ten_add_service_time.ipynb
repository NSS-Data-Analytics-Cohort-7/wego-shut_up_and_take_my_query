# %% [markdown]
# ## How much of a factor does the driver have on headway and on-time performance? The driver is indicated by the OPERATOR variable.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker
# %matplotlib inline

# %%
print(sns.palplot(sns.color_palette("Paired").as_hex()))
print(sns.color_palette("Paired").as_hex())
# Out:
# None
# ['#a6cee3', '#1f78b4', '#b2df8a', '#33a02c', '#fb9a99', '#e31a1c', '#fdbf6f', '#ff7f00', '#cab2d6', '#6a3d9a', '#ffff99', '#b15928']

# %%
df = pd.read_csv(r"C:\Users\jhank\Desktop\DA7\Projects\wego-shut_up_and_take_my_query\data\Headway Data.csv")
#df = pd.read_csv(r"/home/jwhankins177/projects/wego/data/Headway Data.csv")

# %%
df.tail(10)
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 1981705    120221101             1      91057372  2022-11-01          50
# 1981706    120221101             1      91057373  2022-11-01          50
# 1981707    120221101             1      91057381  2022-11-01          55
# 1981708    120221101             1      91057382  2022-11-01          55
# 1981709    120221101             1      91057723  2022-11-01          50
# 1981710    120221101             1      91057724  2022-11-01          50
# 1981711    120221101             1      91057851  2022-11-01          50
# 1981712    120221101             1      91057852  2022-11-01          50
# 1981713    120221101             1      91057881  2022-11-01          56
# 1981714    120221101             1      91057882  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 1981705        8601      2600   329896            0        FROM DOWNTOWN  ...
# 1981706        8601      2600   329896            0        FROM DOWNTOWN  ...
# 1981707        8604      2374   329899            0          TO DOWNTOWN  ...
# 1981708        8604      2374   329899            0          TO DOWNTOWN  ...
# 1981709        9302      2355   329980            0          TO DOWNTOWN  ...
# 1981710        9302      2355   329980            0          TO DOWNTOWN  ...
# 1981711        9950      1880   330003            0          TO DOWNTOWN  ...
# 1981712        9950      1880   330003            0          TO DOWNTOWN  ...
# 1981713        9975      1922   330011            0          TO DOWNTOWN  ...
# 1981714        9975      1922   330011            0          TO DOWNTOWN  ...
#
#         ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# 1981705         NaN       NaN                     0                    0
# 1981706         NaN       NaN                     0                    0
# 1981707         NaN       NaN                     0                    0
# 1981708         NaN       NaN                     0                    0
# 1981709         NaN       NaN                     0                    0
# 1981710         NaN       NaN                     0                    0
# 1981711    7.633333 -2.366667                     1                    0
# 1981712         NaN       NaN                     1                    0
# 1981713         NaN       NaN                     0                    0
# 1981714         NaN       NaN                     0                    0
#
#          ADJUSTED_ONTIME_COUNT STOP_CANCELLED PREV_SCHED_STOP_CANCELLED  \
# 1981705                      1              0                       0.0
# 1981706                      1              0                       NaN
# 1981707                      1              0                       0.0
# 1981708                      1              0                       NaN
# 1981709                      1              0                       0.0
# 1981710                      1              0                       NaN
# 1981711                      0              0                       0.0
# 1981712                      0              0                       NaN
# 1981713                      1              0                       0.0
# 1981714                      1              0                       NaN
#
#         IS_RELIEF  BLOCK_STOP_ORDER  DWELL_IN_MINS
# 1981705         0                23       9.166666
# 1981706         0                24       9.416666
# 1981707         0                 2      31.933333
# 1981708         0                 3       0.000000
# 1981709         0                 2      20.916666
# 1981710         0                 3       1.016666
# 1981711         0                 2       9.900000
# 1981712         0                 3       0.000000
# 1981713         0                 2      19.366666
# 1981714         0                 3       1.683333
#
# [10 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 30 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   CALENDAR_ID                int64
#  1   SERVICE_ABBR               int64
#  2   ADHERENCE_ID               int64
#  3   DATE                       object
#  4   ROUTE_ABBR                 int64
#  5   BLOCK_ABBR                 int64
#  6   OPERATOR                   int64
#  7   TRIP_ID                    int64
#  8   OVERLOAD_ID                int64
#  9   ROUTE_DIRECTION_NAME       object
#  10  TIME_POINT_ABBR            object
#  11  ROUTE_STOP_SEQUENCE        float64
#  12  TRIP_EDGE                  int64
#  13  LATITUDE                   float64
#  14  LONGITUDE                  float64
#  15  SCHEDULED_TIME             object
#  16  ACTUAL_ARRIVAL_TIME        object
#  17  ACTUAL_DEPARTURE_TIME      object
#  18  ADHERENCE                  float64
#  19  SCHEDULED_HDWY             float64
#  20  ACTUAL_HDWY                float64
#  21  HDWY_DEV                   float64
#  22  ADJUSTED_EARLY_COUNT       int64
#  23  ADJUSTED_LATE_COUNT        int64
#  24  ADJUSTED_ONTIME_COUNT      int64
#  25  STOP_CANCELLED             int64
#  26  PREV_SCHED_STOP_CANCELLED  float64
#  27  IS_RELIEF                  int64
#  28  BLOCK_STOP_ORDER           int64
#  29  DWELL_IN_MINS              float64
# dtypes: float64(9), int64(15), object(6)
# memory usage: 453.6+ MB

# %% [markdown]
# Determine length of service per driver

# %%
service = df[['OPERATOR','DATE']]
service
# Out:
#          OPERATOR        DATE
# 0            2088  2021-11-01
# 1            2088  2021-11-01
# 2            2088  2021-11-01
# 3            2088  2021-11-01
# 4            2088  2021-11-01
# ...           ...         ...
# 1981710      2355  2022-11-01
# 1981711      1880  2022-11-01
# 1981712      1880  2022-11-01
# 1981713      1922  2022-11-01
# 1981714      1922  2022-11-01
#
# [1981715 rows x 2 columns]

# %%
df['OPERATOR'].nunique()
# Out:
# 458

# %% [markdown]
# #### Create a dataframe containing relevant info.

# %%
time = df[['OPERATOR','ADJUSTED_ONTIME_COUNT','ADJUSTED_EARLY_COUNT','ADJUSTED_LATE_COUNT']]
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 4 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   OPERATOR               int64
#  1   ADJUSTED_ONTIME_COUNT  int64
#  2   ADJUSTED_EARLY_COUNT   int64
#  3   ADJUSTED_LATE_COUNT    int64
# dtypes: int64(4)
# memory usage: 60.5 MB

# %% [markdown]
# Rename columns

# %%
time.columns=['operator','ontime','early','late']

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 4 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   operator  int64
#  1   ontime    int64
#  2   early     int64
#  3   late      int64
# dtypes: int64(4)
# memory usage: 60.5 MB

# %% [markdown]
# Group by operator

# %%
time_gb = time.groupby(['operator'],as_index = False)['ontime','early','late'].sum()
# Out:
# C:\Users\jhank\AppData\Local\Temp\ipykernel_19104\1898847286.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   time_gb = time.groupby(['operator'],as_index = False)['ontime','early','late'].sum()

# %%
time_gb
# Out:
#      operator  ontime  early  late
# 0           0      98      1    26
# 1          30       0      2     0
# 2          85       0      1     0
# 3          86      24      3     1
# 4          93       5      0     1
# ..        ...     ...    ...   ...
# 453      2622     429     20    52
# 454      2623     195      2     3
# 455      2624      31      0    10
# 456      2630     190     10    28
# 457     22554       2      1     0
#
# [458 rows x 4 columns]

# %%
time_gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   operator  458 non-null    int64
#  1   ontime    458 non-null    int64
#  2   early     458 non-null    int64
#  3   late      458 non-null    int64
# dtypes: int64(4)
# memory usage: 14.4 KB

# %% [markdown]
# Add column with total count

# %%
time_gb['total'] = (time_gb['ontime'] + time_gb['early'] + time_gb['late'])

# %%
time_gb.head()
# Out:
#    operator  ontime  early  late  total
# 0         0      98      1    26    125
# 1        30       0      2     0      2
# 2        85       0      1     0      1
# 3        86      24      3     1     28
# 4        93       5      0     1      6

# %% [markdown]
# Add column with avg on time rate

# %%
time_gb['pct_on_time'] = round((time_gb['ontime']/time_gb['total'])*100,0)

# %%
time_gb['pct_on_time_5'] = round((time_gb['ontime']/time_gb['total'])*100,5)

# %%
time_gb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   operator       458 non-null    int64
#  1   ontime         458 non-null    int64
#  2   early          458 non-null    int64
#  3   late           458 non-null    int64
#  4   total          458 non-null    int64
#  5   pct_on_time    455 non-null    float64
#  6   pct_on_time_5  455 non-null    float64
# dtypes: float64(2), int64(5)
# memory usage: 25.2 KB

# %%
time_gb.head(20)
# Out:
#     operator  ontime  early  late  total  pct_on_time  pct_on_time_5
# 0          0      98      1    26    125         78.0       78.40000
# 1         30       0      2     0      2          0.0        0.00000
# 2         85       0      1     0      1          0.0        0.00000
# 3         86      24      3     1     28         86.0       85.71429
# 4         93       5      0     1      6         83.0       83.33333
# 5        195      14      0     6     20         70.0       70.00000
# 6        212      15      1     8     24         62.0       62.50000
# 7        230     128      0     5    133         96.0       96.24060
# 8        235      39      0     0     39        100.0      100.00000
# 9        242       1      0     0      1        100.0      100.00000
# 10       301      36      3    34     73         49.0       49.31507
# 11       304    7375     22   563   7960         93.0       92.65075
# 12       306    4122    142   407   4671         88.0       88.24663
# 13       310    2514     20   150   2684         94.0       93.66617
# 14       315       1      0     0      1        100.0      100.00000
# 15       326    7826    198   746   8770         89.0       89.23603
# 16       329   10697    242   588  11527         93.0       92.79951
# 17       332   11465    310   862  12637         91.0       90.72565
# 18       341    9359     48   314   9721         96.0       96.27610
# 19       357    6476    324  3675  10475         62.0       61.82339

# %%
# 149 out of 458 or % 32 of drivers have higher than a 90 percent on time count.
time_gb[time_gb['pct_on_time'] > 90.0].count()
# Out:
# operator         149
# ontime           149
# early            149
# late             149
# total            149
# pct_on_time      149
# pct_on_time_5    149
# dtype: int64

# %%
# 366 out of 458 or % 80 of driver have a on time count higher than 75% of the time.
time_gb[time_gb['pct_on_time'] > 75].count()
# Out:
# operator         366
# ontime           366
# early            366
# late             366
# total            366
# pct_on_time      366
# pct_on_time_5    366
# dtype: int64

# %%
# 13 out of 458 or % 3 have a on time count below 50 %.
time_gb[time_gb['pct_on_time'] < 50].count()
# Out:
# operator         13
# ontime           13
# early            13
# late             13
# total            13
# pct_on_time      13
# pct_on_time_5    13
# dtype: int64

# %%
#below50 = time_gb[time_gb['pct_on_time'] < 55.0]

# %%
below50 = time_gb[time_gb['total'] >= 100]

# %%
below50 = below50.sort_values('pct_on_time',ascending = True)

# %%
sns.barplot(y = 'operator', x = 'pct_on_time',
            data=graph50,edgecolor="0",orient = 'h',color='lightblue',order=graph50.sort_values('pct_on_time',ascending = False).operator).set(title = 'Bottom 10 Operators by On Time Percentage',xlabel='On Time %',ylabel='Operator ID')
sns.set_theme(style='whitegrid', font='sans-serif', font_scale=1, color_codes=False, rc=None)
plt.grid(visible = True, axis = 'y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 2
#       1 sns.barplot(y = 'operator', x = 'pct_on_time',
# ----> 2             data=graph50,edgecolor="0",orient = 'h',color='lightblue',order=graph50.sort_values('pct_on_time',ascending = False).operator).set(title = 'Bottom 10 Operators by On Time Percentage',xlabel='On Time %',ylabel='Operator ID')
#       3 sns.set_theme(style='whitegrid', font='sans-serif', font_scale=1, color_codes=False, rc=None)
#       4 plt.grid(visible = True, axis = 'y')
#
# NameError: name 'graph50' is not defined

# %%
#above90 = time_gb[time_gb['pct_on_time'] > 98.0]

# %%
above90
# Out:
#      operator  ontime  early  late  total  pct_on_time  pct_on_time_5
# 25        386    4208      6    58   4272         99.0       98.50187
# 112      1293    4355      3    83   4441         98.0       98.06350
# 189      1733    1217      4    26   1247         98.0       97.59423
# 454      2623     195      2     3    200         98.0       97.50000
# 235      1927    9525     53   243   9821         97.0       96.98605
# ..        ...     ...    ...   ...    ...          ...            ...
# 437      2587     106     15    76    197         54.0       53.80711
# 353      2420     245     43   171    459         53.0       53.37691
# 326      2312    4414    182  5510  10106         44.0       43.67702
# 387      2485      45      1    57    103         44.0       43.68932
# 102      1239      62     88     5    155         40.0       40.00000
#
# [377 rows x 7 columns]

# %%
above90 = time_gb[time_gb['total'] >= 100]

# %%
above90 = above90.sort_values('pct_on_time',ascending = False)

# %%
graphtop = above90.head(10)

# %%
a = sns.barplot(y = 'operator', x = 'pct_on_time',
            data=graphtop,edgecolor="0",orient = 'h',order=graphtop.sort_values('pct_on_time',ascending = False).operator,color='lightblue').set(title = 'Top 10 Operators by On Time Percentage',xlabel='On Time %',ylabel='Operator ID')
sns.set_theme(style='white', palette=('Paired'), font='sans-serif', font_scale=1, color_codes=False, rc=None)

for container in a.containers:
    a.bar_label(container)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [155], line 5
#       1 a = sns.barplot(y = 'operator', x = 'pct_on_time',
#       2             data=graphtop,edgecolor="0",orient = 'h',order=graphtop.sort_values('pct_on_time',ascending = False).operator,color='lightblue').set(title = 'Top 10 Operators by On Time Percentage',xlabel='On Time %',ylabel='Operator ID')
#       3 sns.set_theme(style='white', palette=('Paired'), font='sans-serif', font_scale=1, color_codes=False, rc=None)
# ----> 5 for container in a.containers:
#       6     a.bar_label(container)
#       8 plt.show()
#
# AttributeError: 'list' object has no attribute 'containers'
