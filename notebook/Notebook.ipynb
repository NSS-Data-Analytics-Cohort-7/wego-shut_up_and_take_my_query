# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
from colorama import Fore, Style

# %%
explore_df= pd.read_csv('..\data\Headway Data.csv')

# %%
explore_df
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 2          120211101             1      76447166  2021-11-01           7
# 3          120211101             1      76447167  2021-11-01          50
# 4          120211101             1      76447168  2021-11-01          50
# ...              ...           ...           ...         ...         ...
# 1981710    120221101             1      91057724  2022-11-01          50
# 1981711    120221101             1      91057851  2022-11-01          50
# 1981712    120221101             1      91057852  2022-11-01          50
# 1981713    120221101             1      91057881  2022-11-01          56
# 1981714    120221101             1      91057882  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
explore_df.value_counts()
# Out:
# CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID  DATE        ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID  ROUTE_DIRECTION_NAME  TIME_POINT_ABBR  ROUTE_STOP_SEQUENCE  TRIP_EDGE  LATITUDE   LONGITUDE   SCHEDULED_TIME  ACTUAL_ARRIVAL_TIME  ACTUAL_DEPARTURE_TIME  ADHERENCE   SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV   ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  ADJUSTED_ONTIME_COUNT  STOP_CANCELLED  PREV_SCHED_STOP_CANCELLED  IS_RELIEF  BLOCK_STOP_ORDER  DWELL_IN_MINS
# 120211101    1             76447164      2021-11-01  7           1704        2088      297750   0            TO DOWNTOWN           HBHS             4.0                  1          36.107575  -86.812719  14:10:00        13:59:21             14:12:00               -2.000000   14.0            15.983333     1.983333  0                     0                    1                      0               0.0                        0          2                 12.650000        1
# ...

# %%
total_rows = explore_df['DATE'].value_counts().sum()
total_rows
# Out:
# 1981715

# %%
explore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 30 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   CALENDAR_ID                int64
#  1   SERVICE_ABBR               int64
#  2   ADHERENCE_ID               int64
#  3   DATE                       object
#  4   ROUTE_ABBR                 int64
#  5   BLOCK_ABBR                 int64
#  6   OPERATOR                   int64
#  7   TRIP_ID                    int64
#  8   OVERLOAD_ID                int64
#  9   ROUTE_DIRECTION_NAME       object
#  10  TIME_POINT_ABBR            object
#  11  ROUTE_STOP_SEQUENCE        float64
#  12  TRIP_EDGE                  int64
#  13  LATITUDE                   float64
#  14  LONGITUDE                  float64
#  15  SCHEDULED_TIME             object
#  16  ACTUAL_ARRIVAL_TIME        object
#  17  ACTUAL_DEPARTURE_TIME      object
#  18  ADHERENCE                  float64
# ...

# %%
eda = explore_df[['OPERATOR','ROUTE_ABBR','TRIP_ID','ROUTE_DIRECTION_NAME', 'HDWY_DEV', 'SCHEDULED_HDWY', 'ROUTE_STOP_SEQUENCE','TRIP_EDGE','SCHEDULED_TIME','ACTUAL_ARRIVAL_TIME','ACTUAL_DEPARTURE_TIME','ADHERENCE','ADJUSTED_LATE_COUNT']]

# %%
eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 13 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   OPERATOR               int64
#  1   ROUTE_ABBR             int64
#  2   TRIP_ID                int64
#  3   ROUTE_DIRECTION_NAME   object
#  4   HDWY_DEV               float64
#  5   SCHEDULED_HDWY         float64
#  6   ROUTE_STOP_SEQUENCE    float64
#  7   TRIP_EDGE              int64
#  8   SCHEDULED_TIME         object
#  9   ACTUAL_ARRIVAL_TIME    object
#  10  ACTUAL_DEPARTURE_TIME  object
#  11  ADHERENCE              float64
#  12  ADJUSTED_LATE_COUNT    int64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 196.6+ MB

# %%
eda['ROUTE_ABBR'].value_counts()
# Out:
# 55    362259
# 56    355098
# 52    291150
# 23    250787
# 50    249880
# 3     216446
# 22    153074
# 7     103021
# Name: ROUTE_ABBR, dtype: int64

# %%
eda['ROUTE_ABBR'].value_counts(normalize = True)
# Out:
# 55    0.182801
# 56    0.179187
# 52    0.146918
# 23    0.126550
# 50    0.126093
# 3     0.109222
# 22    0.077243
# 7     0.051986
# Name: ROUTE_ABBR, dtype: float64

# %%
edge_one = eda.loc[explore_df['TRIP_EDGE'] == 1]
edge_one
# Out:
#          OPERATOR  ROUTE_ABBR  TRIP_ID ROUTE_DIRECTION_NAME  HDWY_DEV  \
# 0            2088           7   297750          TO DOWNTOWN  1.983333
# 3            2088          50   297749          TO DOWNTOWN       NaN
# 5            1352          22   298143          TO DOWNTOWN       NaN
# 9            1352          22   298162        FROM DOWNTOWN       NaN
# 12           1352          22   298128          TO DOWNTOWN -0.366667
# ...           ...         ...      ...                  ...       ...
# 1981705      2600          50   329896        FROM DOWNTOWN       NaN
# 1981707      2374          55   329899          TO DOWNTOWN       NaN
# 1981709      2355          50   329980          TO DOWNTOWN       NaN
# 1981711      1880          50   330003          TO DOWNTOWN -2.366667
# 1981713      1922          56   330011          TO DOWNTOWN       NaN
#
#          SCHEDULED_HDWY  ROUTE_STOP_SEQUENCE  TRIP_EDGE SCHEDULED_TIME  \
# ...

# %%
edge_2 = eda1.loc[explore_df['ROUTE_ABBR'] == 55]
edge_2
# Out:
#          ROUTE_ABBR  TRIP_ID ROUTE_DIRECTION_NAME  HDWY_DEV  SCHEDULED_HDWY  \
# 3320             55   300293          TO DOWNTOWN       NaN             NaN
# 3321             55   300293          TO DOWNTOWN       NaN             NaN
# 3322             55   300293          TO DOWNTOWN       NaN             NaN
# 3323             55   300293          TO DOWNTOWN       NaN             NaN
# 3324             55   300293          TO DOWNTOWN       NaN             NaN
# ...             ...      ...                  ...       ...             ...
# 1980230          55   328691          TO DOWNTOWN       NaN             NaN
# 1981375          55   329206          TO DOWNTOWN       NaN             NaN
# 1981376          55   329206          TO DOWNTOWN       NaN             NaN
# 1981707          55   329899          TO DOWNTOWN       NaN             0.0
# 1981708          55   329899          TO DOWNTOWN       NaN             NaN
#
# ...

# %%
eda['OPERATOR'].value_counts()
# Out:
# 1147    15479
# 1587    15352
# 664     15268
# 409     14889
# 1020    14495
#         ...
# 2091        1
# 2219        1
# 242         1
# 315         1
# 2310        1
# Name: OPERATOR, Length: 458, dtype: int64

# %% [markdown]
# ### Weather Information

# %%
weather = pd.read_csv('../data/bna_2022.csv')

# %%
weather
# Out:
#        key        class  expire_time_gmt obs_id   obs_name  valid_time_gmt  \
# 0     KBNA  observation       1641027180   KBNA  Nashville      1641019980
# 1     KBNA  observation       1641030780   KBNA  Nashville      1641023580
# 2     KBNA  observation       1641034380   KBNA  Nashville      1641027180
# 3     KBNA  observation       1641037980   KBNA  Nashville      1641030780
# 4     KBNA  observation       1641041580   KBNA  Nashville      1641034380
# ...    ...          ...              ...    ...        ...             ...
# 7775  KBNA  observation       1646106780   KBNA  Nashville      1646099580
# 7776  KBNA  observation       1646110380   KBNA  Nashville      1646103180
# 7777  KBNA  observation       1646113980   KBNA  Nashville      1646106780
# 7778  KBNA  observation       1646117580   KBNA  Nashville      1646110380
# 7779  KBNA  observation       1646121180   KBNA  Nashville      1646113980
#
#      day_ind  temp  wx_icon  icon_extd  ... clds  water_temp  \
# ...

# %%
weather.drop(['qualifier','qualifier_svrty','blunt_phrase','terse_phrase','water_temp','primary_wave_period','primary_wave_height','primary_swell_period','primary_swell_height','secondary_swell_period','secondary_swell_height','secondary_swell_direction','primary_swell_direction'], axis = 1)
# Out:
#        key        class  expire_time_gmt obs_id   obs_name  valid_time_gmt  \
# 0     KBNA  observation       1641027180   KBNA  Nashville      1641019980
# 1     KBNA  observation       1641030780   KBNA  Nashville      1641023580
# 2     KBNA  observation       1641034380   KBNA  Nashville      1641027180
# 3     KBNA  observation       1641037980   KBNA  Nashville      1641030780
# 4     KBNA  observation       1641041580   KBNA  Nashville      1641034380
# ...    ...          ...              ...    ...        ...             ...
# 7775  KBNA  observation       1646106780   KBNA  Nashville      1646099580
# 7776  KBNA  observation       1646110380   KBNA  Nashville      1646103180
# 7777  KBNA  observation       1646113980   KBNA  Nashville      1646106780
# 7778  KBNA  observation       1646117580   KBNA  Nashville      1646110380
# 7779  KBNA  observation       1646121180   KBNA  Nashville      1646113980
#
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7780 entries, 0 to 7779
# Data columns (total 45 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   key                        7780 non-null   object
#  1   class                      7780 non-null   object
#  2   expire_time_gmt            7780 non-null   int64
#  3   obs_id                     7780 non-null   object
#  4   obs_name                   7780 non-null   object
#  5   valid_time_gmt             7780 non-null   int64
#  6   day_ind                    7780 non-null   object
#  7   temp                       7780 non-null   int64
#  8   wx_icon                    7780 non-null   int64
#  9   icon_extd                  7780 non-null   int64
#  10  wx_phrase                  7780 non-null   object
#  11  pressure_tend              2314 non-null   float64
#  12  pressure_desc              2314 non-null   object
# ...
